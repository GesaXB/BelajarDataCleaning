# %%
import pandas as pd
import numpy as np

# %%
# membuat DataFrame
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1,10, size=(n_rows, n_cols)),
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  6  4  3  4  5
# 1  1  1  9  6  6
# 2  7  6  4  5  8
# 3  7  5  9  7  7
# 4  7  5  8  1  9

# %% [markdown]
# # Membalik Urutan Colom

# %%
df.loc[:, ::-1]
# Out:
#    E  D  C  B  A
# 0  5  4  3  4  6
# 1  6  6  9  1  1
# 2  8  5  4  6  7
# 3  7  7  9  5  7
# 4  9  1  8  5  7

# %% [markdown]
# # Membalik Urutan Baris

# %%
df.loc[:: -1, :]
# Out:
#    A  B  C  D  E
# 4  7  5  8  1  9
# 3  7  5  9  7  7
# 2  7  6  4  5  8
# 1  1  1  9  6  6
# 0  6  4  3  4  5

# %% [markdown]
# # Tanpa mengubah index

# %%
df.loc[::-1].reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  7  5  8  1  9
# 1  7  5  9  7  7
# 2  7  6  4  5  8
# 3  1  1  9  6  6
# 4  6  4  3  4  5
